# %%
import os
import pandas as pd
import pylab as pl
# %pylab inline

assert 'DFDATA' in os.environ
    
dfdata = os.getenv("DFDATA")

#Traffic Volume Counts (2011-2012)
traffic = pd.read_csv(dfdata + '/wng2-85mv/1414246045/wng2-85mv')

traffic.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#    ID  GIS ID  Roadway Name         From                To Direction  \
# 0   1   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 1   2   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 2   3   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 3   4   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 4   5   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
#
#          Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM      ...        \
# 0  01/09/2012             20           10           11      ...
# 1  01/10/2012             21           16            8      ...
# 2  01/11/2012             27           14            6      ...
# 3  01/12/2012             22            7            7      ...
# 4  01/13/2012             31           17            7      ...
#
#    2:00-3:00PM  3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  \
# ...

# %%
traffic = traffic[['2:00-3:00AM','5:00-6:00PM']].dropna()
traffic
# Out:
#       2:00-3:00AM  5:00-6:00PM
# 0              11        120.0
# 1               8        131.0
# 2               6        143.0
# 3               7        144.0
# 4               7        135.0
# 6              12        174.0
# 7              11        171.0
# 8               8        160.0
# 9               7        167.0
# 10              8        159.0
# 12              2        219.0
# 13              5        271.0
# 14              3        220.0
# 15              7        229.0
# 16             10        202.0
# 18              7        301.0
# 19              9        289.0
# 20              6        308.0
# 21              4        368.0
# 22              8        345.0
# 24              5        105.0
# 25              9        116.0
# 26             11        112.0
# 27             17        130.0
# 28             13        132.0
# 30              9        264.0
# 31              5        259.0
# 32              6        275.0
# 33              7        256.0
# ...

# %%
traffic.plot(x = '2:00-3:00AM', y='5:00-6:00PM',kind = 'scatter')
