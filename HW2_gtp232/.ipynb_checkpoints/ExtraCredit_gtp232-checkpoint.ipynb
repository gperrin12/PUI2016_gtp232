# %%
import os
import pandas as pd
import pylab as pl
import datetime
# %pylab inline

assert 'DFDATA' in os.environ
    
dfdata = os.getenv("DFDATA")

#Water Resevoir Levels
#New York City water supply system reservoir levels

waterlevel = pd.read_csv(dfdata + '/zkky-n5j3/1414246141/zkky-n5j3')

waterlevel.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#    Neversink Date                Neversink Elevation  Neversink Storage  \
# 0  03/01/2005 04:00:00 PM +0000              1440.21              35570
# 1  03/02/2005 04:00:00 PM +0000              1440.22              35575
# 2  03/03/2005 04:00:00 PM +0000              1440.21              35570
# 3  03/04/2005 04:00:00 PM +0000              1440.21              35570
# 4  03/05/2005 04:00:00 PM +0000              1440.21              35570
#
#       Rondout Date               Rondout Elevation  Rondout Storage  \
# 0  03/01/2005 04:00:00 PM +0000             835.10          46757.0
# 1  03/02/2005 04:00:00 PM +0000             834.98          46678.0
# 2  03/03/2005 04:00:00 PM +0000             834.84          46585.0
# 3  03/04/2005 04:00:00 PM +0000             834.85          46592.0
# 4  03/05/2005 04:00:00 PM +0000             834.88          46612.0
#
# ...

# %%
waterlevel = waterlevel.rename(columns=lambda x: x.strip()) #remove whitespace from column names
waterlevel = waterlevel[['Pepacton Date','Pepacton Storage']]

waterlevel['Pepacton Date'] = pd.to_datetime(waterlevel['Pepacton Date']).dropna()

waterlevel.head()
# Out:
#         Pepacton Date  Pepacton Storage
# 0 2005-03-01 16:00:00            138986
# 1 2005-03-02 16:00:00            138696
# 2 2005-03-03 16:00:00            138406
# 3 2005-03-04 16:00:00            138045
# 4 2005-03-05 16:00:00            137721

# %%
waterlevel.plot(x = 'Pepacton Date', y = 'Pepacton Storage')
plt.ylabel("Millions of Gallons")
